# %% [markdown]
# Day 8

# %%
# Functions with args
# how positions is important and passing parameters
# prime number code(i in range(2,n) %i)
# Caesor cypher(shift n from plain text , either ASCII or get alphabet list get position of input add n, use modulus )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
