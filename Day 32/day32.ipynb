# %% [markdown]
# Day 32

# %%
#SMTP

# %%
import smtplib

email = "si99alt@gmail.com"
password = 'test'#not correct

connection = smtplib.SMTP("smtp.gmail.com")
connection.starttls()

connection.login(user=email, password=password)

connection.sendmail(from_addr='',to_addrs='',msg='')
connection.close()
#Won't work need to do some things to make it work

#go to gmail, security settingd, on 2 step verification, After that go to app passwords
#Basicvally you'll be using this password for an app you create

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Better is with as it'll close by itself

# %%
#datetime module
#Easy project of sending mail for birthday, using dateteime

# %% [markdown]
# ![image.png](attachment:image.png)
