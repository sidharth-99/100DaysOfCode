# %% [markdown]
# Day 20

# %%
# Creating the snake game part 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Can use this structure for easiness of changing constants

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Use above method for definition
