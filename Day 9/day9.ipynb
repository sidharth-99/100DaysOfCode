# %% [markdown]
# Day 9

# %%
# Dictionaries
# Auction program, check whoo bids the most k,v

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dict can be added like above

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
