# %% [markdown]
# Day 33

# %%
#API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#THe External system here can be an API endpoint

# %%
import requests

response = requests.get(url="http://api.open-notify.org/iss-now.json")

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The above mentioned merthod is better for raising exceptions

# %%
data = response.json()
data
# Out:
# {'iss_position': {'longitude': '-140.3113', 'latitude': '38.9825'},
#  'message': 'success',
#  'timestamp': 1705377275}

# %%
type(data)
# Out:
# dict

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Basically passed a parameter for formatting, and splitted the values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Add this in the end code for final main.py to send mail(Only other difference is using function)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# For running every 1 minute
