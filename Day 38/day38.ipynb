# %%
# Day 38

# %%
import requests
apikey = '7d5250eea6eb2ec66132afd20da592cf'
app_id = 'ce493af2'
url ='https://trackapi.nutritionix.com/v2/natural/nutrients'
header = {
    'Content-Type': 'application/json',
    'x-app-id': app_id ,
    'x-app-key': apikey
  }

# %%
food = input('Tell me What did you eat today?')
body = {
    'query': f'{food}'
}

response =  requests.post(url,headers=header,json=body)

# %%
response.json()
# Out:
# {'foods': [{'food_name': 'biryani',
#    'brand_name': None,
#    'serving_qty': 1,
#    'serving_unit': 'cup',
#    'serving_weight_grams': 205.18,
#    'nf_calories': 291.95,
#    'nf_total_fat': 9.44,
#    'nf_saturated_fat': 1.7,
#    'nf_cholesterol': 48.47,
#    'nf_sodium': 419.16,
#    'nf_total_carbohydrate': 30.95,
#    'nf_dietary_fiber': 1.36,
#    'nf_sugars': 3.2,
#    'nf_protein': 19.65,
#    'nf_potassium': 461.71,
#    'nf_p': 190.5,
#    'full_nutrients': [{'attr_id': 203, 'value': 19.6513},
#     {'attr_id': 204, 'value': 9.4442},
#     {'attr_id': 205, 'value': 30.9518},
#     {'attr_id': 207, 'value': 2.4248},
#     {'attr_id': 208, 'value': 291.9518},
#     {'attr_id': 209, 'value': 5.8718},
#     {'attr_id': 210, 'value': 0.3024},
#     {'attr_id': 211, 'value': 0.6353},
#     {'attr_id': 212, 'value': 0.507},
#     {'attr_id': 213, 'value': 0},
#     {'attr_id': 214, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 142.7144},
# ...

# %%
import datetime
url = 'https://api.sheety.co/e0b50d92c7f48138cb57e5e3dcf61131/myCaloryCounter/workouts'
header = {
    'Content-Type': 'application/json'
}
body = {
    'workout':
    {
        'date':'21/07/2020',
        'time':'15:00:00',	
        'exercise':	'Swimming',
        'duration':22,
        'calories':130
    }
  }

# %%
response = requests.post(url=url,json=body,headers=header)

# %%
response.json()
# Out:
# {'workout': {'date': '21/07/2020',
#   'time': '15:00:00',
#   'exercise': 'Swimming',
#   'duration': 22,
#   'calories': 130,
#   'id': 3}}

# %%
import requests
from datetime import datetime

GENDER = YOUR GENDER
WEIGHT_KG = YOUR WEIGHT
HEIGHT_CM = YOUR HEIGHT
AGE = YOUR AGE

APP_ID = YOUR NUTRITIONIX APP ID
API_KEY = YOUR NUTRITIONIX API KEY

exercise_endpoint = "https://trackapi.nutritionix.com/v2/natural/exercise"
sheet_endpoint = YOUR SHEETY ENDPOINT

exercise_text = input("Tell me which exercises you did: ")

headers = {
    "x-app-id": APP_ID,
    "x-app-key": API_KEY,
}

parameters = {
    "query": exercise_text,
    "gender": GENDER,
    "weight_kg": WEIGHT_KG,
    "height_cm": HEIGHT_CM,
    "age": AGE
}

response = requests.post(exercise_endpoint, json=parameters, headers=headers)
result = response.json()

################### Start of Step 4 Solution ######################

today_date = datetime.now().strftime("%d/%m/%Y")
now_time = datetime.now().strftime("%X")

for exercise in result["exercises"]:
    sheet_inputs = {
        "workout": {
            "date": today_date,
            "time": now_time,
            "exercise": exercise["name"].title(),
            "duration": exercise["duration_min"],
            "calories": exercise["nf_calories"]
        }
    }

    sheet_response = requests.post(sheet_endpoint, json=sheet_inputs)

    print(sheet_response.text)
