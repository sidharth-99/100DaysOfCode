# %% [markdown]
# Day 27

# %%
#Tkinter and GUI

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Basically showing how some functions have default values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def add(*args):
    print(args[2])#pos matters
    sum=0
    for i in args:
        sum+=i
    return sum

# %%
add(1,2,3,100)
# Out:
# 3
# 106

# %%
# **kwargs - keyword arguments
#*args - positional arguments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Basically kwargs takes input as a dictionary

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Basically get function to give None instead of error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#can add padding like that
