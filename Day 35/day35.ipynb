# %%
#Day 35

# %%
#API Authentication, Paid tier etc
#Api Key used for authentication, check rate limit etc

# %%
#use openweather map to check if it'll rain

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Using Twilio to send message if it rains

# %%
# creds.json and python env variables to store api key
