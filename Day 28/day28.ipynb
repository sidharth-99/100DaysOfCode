# %% [markdown]
# Day 28

# %%
#tkinter Pomodore

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# using args for function above

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Dynamic typing in python
